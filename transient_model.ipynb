# %%
#Transient one-layer ocean climate model
from pathlib import Path

import ipywidgets as widgets
import ipywidgets.widgets.interaction as interaction
from ipywidgets import Layout
from IPython.display import display

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#Constants
rho=1000  # kg m-3 density of water
c_p=4218  # J kg-1 K-1 heat capacity
dt=365.2422 * 86400  # seconds in a year

#Parameters
lam = 0.8 # K(Wm-2)-1 climate sensitivity
d_m = 100 # m mixed layer depth
K = 1e-4 #m2 s-1
